# %% [markdown]
# <a href="https://colab.research.google.com/github/nengahresti14-hub/StukturDataD-pertemuan1/blob/main/TUGAS2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# array 1 demensi

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])
print(arr)
# Out:
# [10 20 30 40 50]

# %% [markdown]
# nilai tertinggi

# %%
nilai_tertinggi = np.max(arr)
print(nilai_tertinggi)
# Out:
# 50

# %% [markdown]
# terendah

# %%
nilai_terendah = np.min(arr)
print(nilai_terendah)
# Out:
# 10

# %% [markdown]
# rata rata

# %%
rata_rata= np.mean(arr)
print(rata_rata)
# Out:
# 30.0

# %% [markdown]
# TABEL
