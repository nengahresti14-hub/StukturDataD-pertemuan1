# %% [markdown]
# <a href="https://colab.research.google.com/github/nengahresti14-hub/StukturDataD-pertemuan1/blob/main/latihan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 5 Nama Mahasiswa

# %%
Mahasiswa = ["Andi", "Budi", "Citra", "Devi", " Eko"]
print("list Maasiswa:")
print(Mahasiswa)
# Out:
# list Maasiswa:
# ['Andi', 'Budi', 'Citra', 'Devi', ' Eko']

# %% [markdown]
# Tambahkan 1 nama baru dengan append

# %%
Mahasiswa.append("fajar")
print("setelah ditammbahkan nama baru")
print(Mahasiswa)
# Out:
# setelah ditammbahkan nama baru
# ['Andi', 'Budi', 'Citra', 'Devi', ' Eko', 'fajar']

# %% [markdown]
# Hapus Satu elemen Menggunakan Remove

# %%
Mahasiswa.remove("Budi")
print("setelah remove budi")
print(Mahasiswa)
# Out:
# setelah remove budi
# ['Andi', 'Citra', 'Devi', ' Eko', 'fajar']
